# %% [markdown]
# <a href="https://colab.research.google.com/github/Laxmi0412/customer-churn-retention-analytics/blob/main/notebooks/Telco_customer_churn_IBM_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
import os
os.listdir()
import pandas as pd

df = pd.read_excel("Telco_customer_churn.xlsx")

df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df["Total Charges"] = pd.to_numeric(df["Total Charges"], errors="coerce")
df["Total Charges"] = df["Total Charges"].fillna(0)

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Churn Label")
plt.title("Customer Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x="Contract", hue="Churn Label")
plt.title("Churn by Contract Type")
plt.xticks(rotation=20)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Gender", hue="Churn Label")
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Senior Citizen", hue="Churn Label")
plt.title("Churn by Senior Citizen")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x="Tenure Months", hue="Churn Label", bins=30, kde=True)
plt.title("Churn vs Tenure Months")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="Churn Label", y="Monthly Charges")
plt.title("Monthly Charges vs Churn")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, y="Payment Method", hue="Churn Label")
plt.title("Churn by Payment Method")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x="Internet Service", hue="Churn Label")
plt.title("Churn by Internet Service Type")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
